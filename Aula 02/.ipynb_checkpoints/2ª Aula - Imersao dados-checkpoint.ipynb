# %% [markdown]
# # Aula 2º

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)
# Out:
#                                           Rua  \
# 3463                 Rua Doutor Sérgio Fleury
# 4850                         Rua Dom Henrique
# 1895                         Avenida Rebouças
# 4722                       Rua Alto do Bonfim
# 7331                        Rua Sônia Ribeiro
# 9199                                      NaN
# 9855  Avenida Antônio de Souza Noschese, 996
# 6905                                      NaN
# 9638                       Rua Rodrigo Vieira
# 2750                                 Rua Cuba
#
#                                  Bairro     Cidade  Metragem  Quartos  \
# 3463                    Vila Leopoldina  São Paulo       120        2
# 4850                   Jardim Luzitânia  São Paulo       394        4
# 1895                          Pinheiros  São Paulo       359        3
# 4722  Conjunto Residencial Jardim Canaã  São Paulo       133        3
# 7331                         Campo Belo  São Paulo       250        4
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados['Valor'][0]
# Out:
# 'R$ 7.000.000'

# %%
dados['Valor'][0].split()
# Out:
# ['R$', '7.000.000']

# %%
dados.sample(10)
# Out:
#                                   Rua                Bairro     Cidade  \
# 4568    Rua Silvino de Oliveira Pinto   Jardim Santa Helena  São Paulo
# 7482  Praça Monsenhor Galvão de Sousa        Jardim Guedala  São Paulo
# 8870   Avenida Doutor Cardoso de Melo          Vila Olímpia  São Paulo
# 2713     Rua Raul Adalberto de Campos         Vila Madalena  São Paulo
# 9193                              NaN      Vila Dom Pedro I  São Paulo
# 7200                              NaN  Jardim das Bandeiras  São Paulo
# 1959                              NaN         Jardim Europa  São Paulo
# 2471                              NaN         Jardim Leonor  São Paulo
# 9861                              NaN           Vila Carrão  São Paulo
# 4506       Rua Ministro Sinésio Rocha      Jardim Vera Cruz  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 4568       600        4          6      6
# 7482       558        4          8      6
# 8870       305        4          1      8
# ...

# %%
dados['Valor'].str.split(expand=True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
len(dados['Valor'].str.split(expand=True))
# Out:
# 10008

# %%
data_2= dados['Valor'].str.split(expand=True)
data_2[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %%
dados[['Valor', 'Bairro']]
# Out:
#                                       Valor              Bairro
# 0                              R$ 7.000.000   Planalto Paulista
# 1                              R$ 3.700.000  Jardim dos Estados
# 2                                R$ 380.000     Jardim Reimberg
# 3                                R$ 685.000      Jardim Morumbi
# 4                                R$ 540.000               Mooca
# ...                                     ...                 ...
# 10003                            R$ 665.000          Vila Sofia
# 10004                          R$ 2.300.000     Bosque da Saúde
# 10005                          R$ 1.050.000       Vila da Saúde
# 10006  R$ 2.200\n                      /Mês       Vila Oratório
# 10007                            R$ 270.000         Vila Alpina
#
# [10008 rows x 2 columns]

# %%
dados[['Moeda', 'Valor_anuncio', 'Tipo_anuncio']] = dados['Valor'].str.split(expand=True)
dados
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# ...

# %%
dados[dados['Tipo_anuncio'].isnull()]['Tipo_anuncio'].unique()
# Out:
# array([None], dtype=object)

# %%
dados_vendas = dados[dados['Tipo_anuncio'].isnull()]
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# ...

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   object
#  10  Tipo_anuncio   0 non-null      object
# dtypes: int64(4), object(7)
# memory usage: 858.4+ KB

# %%
dados_vendas['Valor_anuncio'].str.replace('.','').astype(float)
# Out:
# /tmp/ipykernel_3363/3109396543.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_vendas['Valor_anuncio'].str.replace('.','').astype(float)
# 0        7000000.0
# 1        3700000.0
# 2         380000.0
# 3         685000.0
# 4         540000.0
#            ...
# 10002    1500000.0
# 10003     665000.0
# 10004    2300000.0
# 10005    1050000.0
# 10007     270000.0
# Name: Valor_anuncio, Length: 9156, dtype: float64

# %%
dados_vendas['Valor_anuncio'] = dados_vendas['Valor_anuncio'].str.replace('.','').astype(float)
# Out:
# /tmp/ipykernel_3363/356852458.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados_vendas['Valor_anuncio'] = dados_vendas['Valor_anuncio'].str.replace('.','').astype(float)
# /tmp/ipykernel_3363/356852458.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dados_vendas['Valor_anuncio'] = dados_vendas['Valor_anuncio'].str.replace('.','').astype(float)

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   float64
#  10  Tipo_anuncio   0 non-null      object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 858.4+ KB

# %%
dados_vendas['Valor_anuncio'].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
pd.set_option("display.precision", 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio
# count   9156.00  9156.00    9156.00 9156.00        9156.00
# mean     434.42     3.45       3.80    3.96     3052202.96
# std     7856.42     1.05       1.97    2.60     3944208.19
# min       10.00     1.00       1.00    1.00       13000.00
# 25%      168.00     3.00       2.00    2.00      890000.00
# 50%      276.00     3.00       4.00    4.00     1800000.00
# 75%      450.00     4.00       5.00    5.00     3500000.00
# max   750000.00    16.00      40.00   50.00    65000000.00

# %%
dados.describe()
# Out:
#        Metragem  Quartos  Banheiros    Vagas
# count  10008.00 10008.00   10008.00 10008.00
# mean     442.30     3.48       3.88     4.10
# std     7515.38     1.06       1.99     2.82
# min       10.00     1.00       1.00     1.00
# 25%      173.00     3.00       2.00     2.00
# 50%      290.00     3.00       4.00     4.00
# 75%      460.25     4.00       5.00     5.00
# max   750000.00    16.00      40.00    50.00

# %%
dados[['Rua', 'Cidade', 'Bairro']].describe()
# Out:
#                       Rua     Cidade             Bairro
# count                6574      10008               9996
# unique               3130          1                701
# top     Rua Alberto Faria  São Paulo  Alto de Pinheiros
# freq                   24      10008                409

# %% [markdown]
# - Usando seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.figure(figsize=(12,8))
ax = sns.histplot(data = dados_vendas, x='Valor_anuncio', kde=True)
ax.set_title('Histograma do valor')
plt.xlim(50, 10000000)
plt.show()

# %% [markdown]
# fim
