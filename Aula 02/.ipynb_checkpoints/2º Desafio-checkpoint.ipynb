# %% [markdown]
# # 2º Desafio - alura - imersao dados
#
# - Criar uma escala de valores em milhões
# - Deixar o gráfico do histograma de valores legível (alterar labels, cores, título, escala)
# - Preço do metro quadrado por bairro e plotar em um gráfico ideal
# - Explorar as bibliotecas de visualizações e colocar as suas conclusão
# - Pesquisar um visualização para analisar os quartis, mediana e outliers

# %% [markdown]
# ### Importando pandas para manipular dfs

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %% [markdown]
# ### Armazenando a coluna valor com a retirada do sifrão e outros nomes (categoricas)

# %%
'''
Transformando e armazenando a coluna valores
Transformando dados de valores a tipo float
limpeza do df
excluindo algumas colunas
'''

dados[['primeira', 'Novo_valor', 'ultima']] = dados['Valor'].str.split(expand=True)
dados = dados.drop(['primeira', 'ultima'], axis=1)
dados['Novo_valor'] = dados['Novo_valor'].str.replace('.','').astype(float)
# Out:
# /tmp/ipykernel_13753/1887344755.py:10: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dados['Novo_valor'] = dados['Novo_valor'].str.replace('.','').astype(float)

# %%
dados.sample(5)
# Out:
#                          Rua                        Bairro     Cidade  \
# 9382          Rua Frei Rolim               Bosque da Saúde  São Paulo
# 2170                     NaN                       Butantã  São Paulo
# 6812  Rua Cardoso de Almeida                      Perdizes  São Paulo
# 5161                     NaN                       Morumbi  São Paulo
# 8362    Rua François Carlier  Vila Santa Teresa (Zona Sul)  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas  \
# 9382       226        3          5      4
# 2170       605        4          4      4
# 6812       355        5          4      5
# 5161       300        3          3      4
# 8362        94        3          3      2
#
#                                      Valor  Novo_valor
# 9382                            R$ 920.000    920000.0
# 2170                          R$ 3.500.000   3500000.0
# 6812  R$ 7.000\n                      /Mês      7000.0
# 5161                          R$ 1.950.000   1950000.0
# 8362                            R$ 532.000    532000.0

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rua         6574 non-null   object
#  1   Bairro      9996 non-null   object
#  2   Cidade      10008 non-null  object
#  3   Metragem    10008 non-null  int64
#  4   Quartos     10008 non-null  int64
#  5   Banheiros   10008 non-null  int64
#  6   Vagas       10008 non-null  int64
#  7   Valor       10008 non-null  object
#  8   Novo_valor  10008 non-null  float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 703.8+ KB

# %%
dados.describe()
# Out:
#             Metragem       Quartos     Banheiros         Vagas    Novo_valor
# count   10008.000000  10008.000000  10008.000000  10008.000000  1.000800e+04
# mean      442.300659      3.483114      3.879097      4.097222  2.794170e+06
# std      7515.379389      1.064200      1.988467      2.824014  3.866249e+06
# min        10.000000      1.000000      1.000000      1.000000  1.650000e+03
# 25%       173.000000      3.000000      2.000000      2.000000  7.500000e+05
# 50%       290.000000      3.000000      4.000000      4.000000  1.600000e+06
# 75%       460.250000      4.000000      5.000000      5.000000  3.350000e+06
# max    750000.000000     16.000000     40.000000     50.000000  6.500000e+07

# %%
dados_ = pd.DataFrame()
dados_ = dados
dados_['Novo_valor_menor_que_1m'] = dados.loc[(dados['Novo_valor'] < 1000000), 'Novo_valor']
dados_['Novo_valor_entre_1m_10m'] = dados.loc[(dados['Novo_valor'] > 1000000) & (dados['Novo_valor'] < 10000000), 'Novo_valor']
dados_['Novo_valor_entre_10m_60m'] = dados.loc[(dados['Novo_valor'] > 10000000) & (dados['Novo_valor'] < 60000000), 'Novo_valor']

dados_.sample(5)
# Out:
#                               Rua             Bairro     Cidade  Metragem  \
# 9295                          NaN            Tatuapé  São Paulo       267
# 3468                          NaN     Jardim Guedala  São Paulo       890
# 5317                          NaN  Parque Novo Mundo  São Paulo       460
# 8440           Rua Roque Petrella      Vila Cordeiro  São Paulo       271
# 6043  Rua Francisco Teles Dourado   Jardim Prudência  São Paulo       320
#
#       Quartos  Banheiros  Vagas                                  Valor  \
# 9295        4          3      4                             R$ 890.000
# 3468        4          1      4  R$ 25.000\n                      /Mês
# 5317        6          6     12                           R$ 2.800.000
# 8440        3          5      4  R$ 12.000\n                      /Mês
# 6043        4          3      4                           R$ 1.380.000
#
#       Novo_valor  Novo_valor_menor_que_1m  Novo_valor_entre_1m_10m  \
# 9295    890000.0                 890000.0                      NaN
# 3468     25000.0                  25000.0                      NaN
# 5317   2800000.0                      NaN                2800000.0
# 8440     12000.0                  12000.0                      NaN
# 6043   1380000.0                      NaN                1380000.0
#
#       Novo_valor_entre_10m_60m
# 9295                       NaN
# 3468                       NaN
# 5317                       NaN
# 8440                       NaN
# 6043                       NaN

# %%
dados
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10006         Rua Manuel Onha, , 514        Vila Oratório  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas  \
# 0          1000        4          8      6
# 1           496        4          4      4
# 2           125        4          3      2
# 3           310        3          2      4
# 4           100        3          2      2
# ...         ...      ...        ...    ...
# 10003        95        2          2      2
# 10004       605        8          7      5
# 10005       205        3          3      6
# 10006       185        3          2      2
# 10007       122        3          2      2
#
#                                       Valor  Novo_valor  \
# 0                              R$ 7.000.000   7000000.0
# 1                              R$ 3.700.000   3700000.0
# 2                                R$ 380.000    380000.0
# 3                                R$ 685.000    685000.0
# 4                                R$ 540.000    540000.0
# ...                                     ...         ...
# 10003                            R$ 665.000    665000.0
# 10004                          R$ 2.300.000   2300000.0
# 10005                          R$ 1.050.000   1050000.0
# 10006  R$ 2.200\n                      /Mês      2200.0
# 10007                            R$ 270.000    270000.0
#
#        Novo_valor_menor_que_1m  Novo_valor_entre_1m_10m  \
# 0                          NaN                7000000.0
# 1                          NaN                3700000.0
# 2                     380000.0                      NaN
# 3                     685000.0                      NaN
# 4                     540000.0                      NaN
# ...                        ...                      ...
# 10003                 665000.0                      NaN
# 10004                      NaN                2300000.0
# 10005                      NaN                1050000.0
# 10006                   2200.0                      NaN
# 10007                 270000.0                      NaN
#
#        Novo_valor_entre_10m_60m
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ...                         ...
# 10003                       NaN
# 10004                       NaN
# 10005                       NaN
# 10006                       NaN
# 10007                       NaN
#
# [10008 rows x 12 columns]

# %% [markdown]
# ### Importando seaborn and matplot.pyplot para plotar uns gráficos

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Gráfico geral dos imóveis

# %%
sns.set()
sns.set_theme(style='whitegrid')
plt.figure(figsize=(10,10))
sns.histplot(data = dados_, x='Novo_valor', kde=True)
plt.xlabel('Valores dos imóveis (Milhões)', labelpad=25, )
plt.ylabel('Quantidade dos imóveis', labelpad=25)
plt.ticklabel_format(style='plain', axis='x')
plt.xlim(0,12000000)
plt.show()

# %% [markdown]
# ### Gráfico de imóveis com valores entre 0 e 1 milhão

# %%
sns.set()
sns.set_theme(style='whitegrid')
plt.figure(figsize=(10,10))
sns.histplot(data = dados_, x='Novo_valor_menor_que_1m', kde=True, color='Green')
plt.xlabel('Valores dos imóveis (Milhões)', labelpad=25, )
plt.ylabel('Quantidade dos imóveis', labelpad=25)
plt.ticklabel_format(style='plain', axis='x')
plt.show()

# %% [markdown]
# ### Gráfico de imóveis com valores entre 1 milhão e 10 milhões

# %%
sns.set()
sns.set_theme(style='whitegrid')
plt.figure(figsize=(10,10))
sns.histplot(data = dados_, x='Novo_valor_entre_1m_10m', kde=True, color='Yellow')
plt.xlabel('Valores dos imóveis (Milhões)', labelpad=25, )
plt.ylabel('Quantidade dos imóveis', labelpad=25)
plt.ticklabel_format(style='plain', axis='x')
plt.show()

# %% [markdown]
# ### Gráfico de imóveis com valores entre 10 milhões e 60 milhões

# %%
sns.set()
sns.set_theme(style='whitegrid')
plt.figure(figsize=(10,10))
sns.histplot(data = dados_, x='Novo_valor_entre_10m_60m', kde=True, color='Red')
plt.xlabel('Valores dos imóveis (Milhões)', labelpad=25, )
plt.ylabel('Quantidade dos imóveis', labelpad=25)
plt.ticklabel_format(style='plain', axis='x')
plt.show()

# %% [markdown]
# ### Preço do metro quadrado por bairro, plotar

# %%
dados = dados.drop(['Novo_valor_menor_que_1m',
                    'Novo_valor_entre_1m_10m',
                    'Novo_valor_entre_10m_60m'], axis=1)
pd.set_option("display.precision", 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
dados.head(10)
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 5                 Rua Graham Bell         Santo Amaro  São Paulo       440
# 6        Rua Francisco Paulo, 31    Cidade Mãe do Céu  São Paulo       145
# 7     Rua Guilherme Valente, 150     Jardim Vergueiro  São Paulo       150
# 8         Rua Sagrada Família, 8       Jardim Benfica  São Paulo        48
# 9                      Rua Tapaji         Vila Alpina  São Paulo       114
#
#    Quartos  Banheiros  Vagas         Valor  Novo_valor
# 0        4          8      6  R$ 7.000.000  7000000.00
# 1        4          4      4  R$ 3.700.000  3700000.00
# 2        4          3      2    R$ 380.000   380000.00
# 3        3          2      4    R$ 685.000   685000.00
# 4        3          2      2    R$ 540.000   540000.00
# 5        4          4      6  R$ 1.980.000  1980000.00
# 6        4          4      2    R$ 850.000   850000.00
# 7        2          2      2    R$ 450.000   450000.00
# 8        2          1      1    R$ 199.900   199900.00
# 9        3          3      2    R$ 585.000   585000.00

# %%
dados['Valor_m2'] = dados['Novo_valor']/dados['Metragem']
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor  Novo_valor  Valor_m2
# 0        4          8      6  R$ 7.000.000  7000000.00   7000.00
# 1        4          4      4  R$ 3.700.000  3700000.00   7459.68
# 2        4          3      2    R$ 380.000   380000.00   3040.00
# 3        3          2      4    R$ 685.000   685000.00   2209.68
# 4        3          2      2    R$ 540.000   540000.00   5400.00

# %%
dados.groupby('Bairro').mean()
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Novo_valor  Valor_m2
# Bairro
# Aclimação            253.06     3.32       3.08   2.91  1583696.66   6875.85
# Alto da Boa Vista    418.88     4.12       5.12   4.62  2391250.00   5849.57
# Alto da Lapa         294.34     3.15       3.79   3.91  1938418.49   7078.57
# Alto da Mooca        270.05     3.30       2.60   3.65  1184170.00   5691.74
# Alto de Pinheiros    433.44     3.94       4.84   5.00  4317023.95  10172.23
# ...                     ...      ...        ...    ...         ...       ...
# Vila Água Funda      152.20     2.60       2.20   2.60   652000.00   4467.13
# Água Branca          191.00     3.15       3.08   2.46  1132653.85   6711.20
# Água Fria            165.42     2.83       3.42   2.50   927083.33   5841.10
# Água Funda           139.00     3.00       2.50   2.00   545000.00   3876.86
# Água Rasa            340.25     3.50       3.25   5.25   540875.00   3386.88
#
# [701 rows x 6 columns]

# %%
bairro_agrupado = dados.groupby("Bairro").sum()
bairro_agrupado['Valor_m2_bairro'] = bairro_agrupado['Novo_valor']/bairro_agrupado['Metragem']
bairro_agrupado
# Out:
#                    Metragem  Quartos  Banheiros  Vagas    Novo_valor  \
# Bairro
# Aclimação             22269      292        271    256  139365306.00
# Alto da Boa Vista      3351       33         41     37   19130000.00
# Alto da Lapa          25313      271        326    336  166703990.00
# Alto da Mooca          5401       66         52     73   23683400.00
# Alto de Pinheiros    177279     1611       1979   2047 1765662795.00
# ...                     ...      ...        ...    ...           ...
# Vila Água Funda         761       13         11     13    3260000.00
# Água Branca            2483       41         40     32   14724500.00
# Água Fria              1985       34         41     30   11125000.00
# Água Funda              278        6          5      4    1090000.00
# Água Rasa              2722       28         26     42    4327000.00
#
#                     Valor_m2  Valor_m2_bairro
# Bairro
# Aclimação          605074.50          6258.27
# Alto da Boa Vista   46796.55          5708.74
# Alto da Lapa       608757.03          6585.71
# Alto da Mooca      113834.80          4385.00
# Alto de Pinheiros 4160443.13          9959.80
# ...                      ...              ...
# Vila Água Funda     22335.64          4283.84
# Água Branca         87245.62          5930.12
# Água Fria           70093.25          5604.53
# Água Funda           7753.73          3920.86
# Água Rasa           27095.03          1589.64
#
# [701 rows x 7 columns]

# %%
#describe da vila mariana de todo conjunto de bairros
bairro_agrupado.groupby('Bairro').mean().loc['Vila Mariana']
# Out:
# Metragem              42986.00
# Quartos                 621.00
# Banheiros               594.00
# Vagas                   539.00
# Novo_valor        299460400.00
# Valor_m2            1337840.70
# Valor_m2_bairro        6966.46
# Name: Vila Mariana, dtype: float64

# %%
#describe da vila mariana de todo conjunto de bairros agrupados
#media das médias
bairro_agrupado.groupby('Bairro').mean().loc['Vila Mariana']
# Out:
# Metragem              42986.00
# Quartos                 621.00
# Banheiros               594.00
# Vagas                   539.00
# Novo_valor        299460400.00
# Valor_m2            1337840.70
# Valor_m2_bairro        6966.46
# Name: Vila Mariana, dtype: float64

# %% [markdown]
# ### Plotando os gráficos referente a esse index

# %%
top_bairros = dados["Bairro"].value_counts()[:10].index
top_bairros
# Out:
# Index(['Alto de Pinheiros', 'Jardim Guedala', 'Jardim Paulista',
#        'Brooklin Paulista', 'Jardim Europa', 'Cidade Jardim', 'Vila Madalena',
#        'Pacaembu', 'Planalto Paulista', 'Jardim Leonor'],
#       dtype='object')

# %%
bairro_agrupado.reset_index(inplace=True)
bairro_agrupado
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas    Novo_valor  \
# 0            Aclimação     22269      292        271    256  139365306.00
# 1    Alto da Boa Vista      3351       33         41     37   19130000.00
# 2         Alto da Lapa     25313      271        326    336  166703990.00
# 3        Alto da Mooca      5401       66         52     73   23683400.00
# 4    Alto de Pinheiros    177279     1611       1979   2047 1765662795.00
# ..                 ...       ...      ...        ...    ...           ...
# 696    Vila Água Funda       761       13         11     13    3260000.00
# 697        Água Branca      2483       41         40     32   14724500.00
# 698          Água Fria      1985       34         41     30   11125000.00
# 699         Água Funda       278        6          5      4    1090000.00
# 700          Água Rasa      2722       28         26     42    4327000.00
#
#       Valor_m2  Valor_m2_bairro
# 0    605074.50          6258.27
# 1     46796.55          5708.74
# 2    608757.03          6585.71
# 3    113834.80          4385.00
# 4   4160443.13          9959.80
# ..         ...              ...
# 696   22335.64          4283.84
# 697   87245.62          5930.12
# 698   70093.25          5604.53
# 699    7753.73          3920.86
# 700   27095.03          1589.64
#
# [701 rows x 8 columns]

# %%
valor_m2_bairro_sort = bairro_agrupado.sort_values(by='Valor_m2_bairro',
                                                   ascending=False).query("Bairro in @top_bairros")
valor_m2_bairro_sort
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas    Novo_valor  \
# 157      Jardim Europa    134776      912       1145   1210 2415280900.00
# 229    Jardim Paulista    150266     1194       1428   1384 2137264000.00
# 4    Alto de Pinheiros    177279     1611       1979   2047 1765662795.00
# 566      Vila Madalena     74967      823        882    811  583630130.00
# 340           Pacaembu    113843      866       1000   1223  868419300.00
# 57       Cidade Jardim    160387      952       1192   1420 1165271900.00
# 19   Brooklin Paulista     79948      873        976    935  476052909.00
# 398  Planalto Paulista     63248      674        812    776  375035400.00
# 189      Jardim Leonor    109666      760       1037   1003  646734269.00
# 170     Jardim Guedala   1002116     1649       2310   2441 1802092387.00
#
#       Valor_m2  Valor_m2_bairro
# 157 4194287.26         17920.70
# 229 4281894.20         14223.20
# 4   4160443.13          9959.80
# 566 1793987.29          7785.16
# 340 1754507.69          7628.22
# 57  1637133.78          7265.38
# 19  1627982.31          5954.53
# 398 1186723.88          5929.60
# 189 1116376.09          5897.31
# 170 2835517.49          1798.29

# %%
sns.set()
palette_platform = sns.light_palette("black",19,reverse=True )
sns.set_theme(style='whitegrid')
plt.figure(figsize=(10,10))
sns.barplot(y='Bairro', x='Valor_m2_bairro', data=valor_m2_bairro_sort, palette=palette_platform)
plt.xlabel('Valor M² dos imóveis por bairro', labelpad=25, )
plt.ylabel('Imóveis', labelpad=25)
plt.show()

# %%
sns.set()
#palette_platform = sns.light_palette("black",19,reverse=True )
sns.set_theme(style='whitegrid')
plt.figure(figsize=(10,10))
ax = sns.boxplot(data = dados.query("Bairro in @top_bairros"), x="Bairro", y="Novo_valor")
plt.xlabel('Valor M² dos imóveis por bairro', labelpad=25, )
plt.ylabel('Imóveis', labelpad=12)
plt.xticks(rotation=45)
ax.tick_params(labelsize=20)
plt.show()
